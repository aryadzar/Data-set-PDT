# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/aryadzar/Data-set-PDT/main/aqidataset.csv")
df
# Out:
#        Unnamed: 0        Date  Overall AQI Value Main Pollutant  \
# 0               0  01/01/2023                 28          Ozone
# 1               1  01/02/2023                 26          Ozone
# 2               2  01/03/2023                 21          Ozone
# 3               3  01/04/2023                 25          Ozone
# 4               4  01/05/2023                 31          Ozone
# ...           ...         ...                ...            ...
# 10919       10919  12/27/2023                 54          PM2.5
# 10920       10920  12/28/2023                 41          PM2.5
# 10921       10921  12/29/2023                 41          Ozone
# 10922       10922  12/30/2023                 42          Ozone
# 10923       10923  12/31/2023                 60          PM2.5
#
#                           Site Name (of Overall AQI) Site ID (of Overall AQI)  \
# 0                                   Connecticut Hill              36-109-9991
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Overall AQI Value', 'Main Pollutant',
#        'Site Name (of Overall AQI)', 'Site ID (of Overall AQI)',
#        'Source (of Overall AQI)', 'Ozone', 'PM25', 'CO', 'PM10', 'NO2',
#        'AQI category', 'city', 'state'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10924 entries, 0 to 10923
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  10924 non-null  int64
#  1   Date                        10924 non-null  object
#  2   Overall AQI Value           10924 non-null  int64
#  3   Main Pollutant              10924 non-null  object
#  4   Site Name (of Overall AQI)  10790 non-null  object
#  5   Site ID (of Overall AQI)    10924 non-null  object
#  6   Source (of Overall AQI)     10924 non-null  object
#  7   Ozone                       10575 non-null  object
#  8   PM25                        10924 non-null  object
#  9   CO                          8395 non-null   object
#  10  PM10                        9853 non-null   object
#  11  NO2                         8760 non-null   object
#  12  AQI category                10924 non-null  object
# ...

# %%
# Preprocess "Ozone" column to remove non-numeric characters and convert to numeric type
df["Ozone"] = pd.to_numeric(df["Ozone"], errors="coerce")

df["Ozone"].fillna(df["Ozone"].median(), inplace=True)

df
# Out:
#        Unnamed: 0        Date  Overall AQI Value Main Pollutant  \
# 0               0  01/01/2023                 28          Ozone
# 1               1  01/02/2023                 26          Ozone
# 2               2  01/03/2023                 21          Ozone
# 3               3  01/04/2023                 25          Ozone
# 4               4  01/05/2023                 31          Ozone
# ...           ...         ...                ...            ...
# 10919       10919  12/27/2023                 54          PM2.5
# 10920       10920  12/28/2023                 41          PM2.5
# 10921       10921  12/29/2023                 41          Ozone
# 10922       10922  12/30/2023                 42          Ozone
# 10923       10923  12/31/2023                 60          PM2.5
#
#                           Site Name (of Overall AQI) Site ID (of Overall AQI)  \
# 0                                   Connecticut Hill              36-109-9991
# ...

# %%
df.describe().transpose()
# Out:
#                      count         mean          std  min      25%     50%  \
# Unnamed: 0         10924.0  5461.500000  3153.631505  0.0  2730.75  5461.5
# Overall AQI Value  10924.0    53.218876    27.553514  0.0    38.00    47.0
# Ozone              10924.0    46.716404    23.674409  1.0    34.00    41.0
#
#                        75%      max
# Unnamed: 0         8192.25  10923.0
# Overall AQI Value    61.00    688.0
# Ozone                48.00    210.0
